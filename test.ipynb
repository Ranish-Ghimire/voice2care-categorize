# %%
print("testing")
# Out:
# testing

# %%
import pandas as pd

# %%
df = pd.read_csv('./combined_df.csv')

# %%
df.count()
# Out:
#                                                input     label  \
# 0  I've been struggling with my mental health for...   sadness
# 1  I've been feeling overwhelmed with my caregivi...  surprise
# 2  I've been feeling constantly anxious and unabl...      fear
# 3  My mom has Alzheimer's, and I've been her prim...   sadness
# 4  I've tried setting boundaries, but it feels li...   sadness
#
#                                               output              category
# 0  I understand that you've been dealing with a s...     Depression & Mood
# 1  Your situation is complex, and it's important ...  Work & Career Stress
# 2  I can see that you're dealing with a great dea...       Anxiety & Panic
# 3  I'm sorry to hear that your siblings' demands ...         Family Issues
# 4  Your concerns are valid, and it's crucial to p...  Work & Career Stress

# %%
df["input"][4]
# Out:
# "I've tried setting boundaries, but it feels like I'm constantly being pulled in different directions. I feel guilty for not being able to help my siblings, but I also know that I can't continue to neglect my mom's needs. I'm worried that if I don't find a way to manage these demands, I'll burn out and won't be able to care for her effectively."
